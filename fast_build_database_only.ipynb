# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from sqlalchemy import create_engine
import gmaps

# Import API key
from api_keys import weather_api_key
from api_keys import google_key
from config import username
from config import password


gmaps.configure(api_key = google_key)

# %%
# LOAD - Perform the loading of the data into the sql server here:
rds_connection_string = f'{username}:{password}@localhost:5432/hurricanes'
engine = create_engine(f'postgresql://{rds_connection_string}')

# Confirm the table name in the database:
engine.table_names()
# Out:
# ['hurricanes']

# %%
csv_file = "Resources/final_database.csv"
recovered_df = pd.read_csv(csv_file)
to_sql_df = recovered_df
recovered_df.head(50)
# Out:
#     Unnamed: 0  Unnamed: 0.1        id     name  date_stamp  time_stamp  \
# 0            0             0  AL011851  UNNAMED    18510625           0
# 1            1             1  AL011851  UNNAMED    18510625         600
# 2            2             2  AL011851  UNNAMED    18510625        1200
# 3            3             3  AL011851  UNNAMED    18510625        1800
# 4            4             4  AL011851  UNNAMED    18510625        2100
# 5            5             5  AL011851  UNNAMED    18510626           0
# 6            6             6  AL011851  UNNAMED    18510626         600
# 7            7             7  AL011851  UNNAMED    18510626        1200
# 8            8             8  AL011851  UNNAMED    18510626        1800
# 9            9             9  AL011851  UNNAMED    18510627           0
# 10          10            10  AL011851  UNNAMED    18510627         600
# 11          11            11  AL011851  UNNAMED    18510627        1200
# 12          12            12  AL011851  UNNAMED    18510627        1800
# 13          13            13  AL011851  UNNAMED    18510628           0
# 14          14            14  AL021851  UNNAMED    18510705        1200
# 15          15            15  AL031851  UNNAMED    18510710        1200
# 16          16            16  AL041851  UNNAMED    18510816           0
# 17          17            17  AL041851  UNNAMED    18510816         600
# 18          18            18  AL041851  UNNAMED    18510816        1200
# 19          19            19  AL041851  UNNAMED    18510816        1800
# 20          20            20  AL041851  UNNAMED    18510817           0
# 21          21            21  AL041851  UNNAMED    18510817         600
# 22          22            22  AL041851  UNNAMED    18510817        1200
# 23          23            23  AL041851  UNNAMED    18510817        1800
# 24          24            24  AL041851  UNNAMED    18510818           0
# 25          25            26  AL041851  UNNAMED    18510818        1200
# 26          26            27  AL041851  UNNAMED    18510818        1800
# 27          27            28  AL041851  UNNAMED    18510819           0
# 28          28            29  AL041851  UNNAMED    18510819         600
# 29          29            30  AL041851  UNNAMED    18510819        1200
# 30          30            31  AL041851  UNNAMED    18510819        1800
# 31          31            32  AL041851  UNNAMED    18510820           0
# 32          32            33  AL041851  UNNAMED    18510820         600
# 33          33            34  AL041851  UNNAMED    18510820        1200
# 34          34            35  AL041851  UNNAMED    18510820        1800
# 35          35            36  AL041851  UNNAMED    18510821           0
# 36          36            37  AL041851  UNNAMED    18510821         600
# 37          37            38  AL041851  UNNAMED    18510821        1200
# 38          38            39  AL041851  UNNAMED    18510821        1800
# 39          39            40  AL041851  UNNAMED    18510822           0
# 40          40            41  AL041851  UNNAMED    18510822         600
# 41          41            42  AL041851  UNNAMED    18510822        1200
# 42          42            43  AL041851  UNNAMED    18510822        1800
# 43          43            44  AL041851  UNNAMED    18510823           0
# 44          44            45  AL041851  UNNAMED    18510823         600
# 45          45            46  AL041851  UNNAMED    18510823        1200
# 46          46            47  AL041851  UNNAMED    18510823        1800
# 47          47            48  AL041851  UNNAMED    18510823        2100
# 48          48            49  AL041851  UNNAMED    18510824           0
# 49          49            50  AL041851  UNNAMED    18510824         600
#
# 1           28.0          -95.4              Freeport        United States
# 2           28.0          -96.0           Port Lavaca        United States
# 3           28.1          -96.5           Port Lavaca        United States
# 4           28.2          -96.8              Rockport        United States
# 5           28.2          -97.0              Rockport        United States
# 6           28.3          -97.6              Beeville        United States
# 7           28.4          -98.3              Beeville        United States
# 8           28.6          -98.9            Pleasanton        United States
# 9           29.0          -99.4                 Hondo        United States
# 10          29.5          -99.8                Uvalde        United States
# 11          30.0         -100.0                Uvalde        United States
# 12          30.5         -100.1            San Angelo        United States
# 13          31.0         -100.2            San Angelo        United States
# 14          22.2          -97.6               Miramar               Mexico
# 15          12.0          -60.0           Scarborough  Trinidad and Tobago
# 16          13.4          -48.0             Sinnamary        French Guiana
# 17          13.7          -49.5             Sinnamary        French Guiana
# 18          14.0          -51.0             Bathsheba             Barbados
# 19          14.4          -52.8             Bathsheba             Barbados
# 20          14.9          -54.6             Bathsheba             Barbados
# 21          15.4          -56.5             Bathsheba             Barbados
# 22          15.9          -58.5            Le Vauclin           Martinique
# 23          16.1          -60.4        Saint-Francois           Guadeloupe
# 24          16.6          -62.5           Charlestown  St. Kitts and Nevis
# 25          17.2          -66.0                Arroyo        United States
# 26          17.6          -67.6             Cabo Rojo        United States
# 27          18.0          -69.3  San Pedro De Macoris   Dominican Republic
# 28          18.4          -71.1                Tamayo   Dominican Republic
# 29          18.9          -72.6             Verrettes                Haiti
# 30          19.4          -74.3               Jeremie                Haiti
# 31          19.9          -75.9      Santiago De Cuba                 Cuba
# 32          20.5          -77.6               Amancio                 Cuba
# 33          21.2          -79.0             Venezuela                 Cuba
# 34          21.9          -80.4            Cienfuegos                 Cuba
# 35          22.6          -81.4      Pedro Betancourt                 Cuba
# 36          23.2          -82.5                 Bauta                 Cuba
# 37          23.9          -83.6           Bahia Honda                 Cuba
# 38          24.4          -84.3           Bahia Honda                 Cuba
# 39          25.0          -84.9           Bahia Honda                 Cuba
# 40          25.6          -85.5                Venice        United States
# 41          26.2          -86.0      Saint Pete Beach        United States
# 42          26.8          -86.3           Panama City        United States
# 43          27.4          -86.5           Panama City        United States
# 44          28.0          -86.6           Panama City        United States
# 45          28.5          -86.6                Destin        United States
# 46          29.6          -86.1           Panama City        United States
# 47          30.1          -85.7           Panama City        United States
# 48          30.7          -85.1            Bainbridge        United States
# 49          31.6          -84.1                Albany        United States

# %%
# LOAD the data INTO the SQL server database
to_sql_df.to_sql(name='hurricanes', con=engine, if_exists='replace', index=True)

# %%
#############################################

# %%
# Store a backup copy of the dataframe so that we don't have to rerun the above.
# This will allow others to quickly spin up the full-size database
#to_sql_df.to_csv("Resources/final_database.csv", index=True, header=True)

# %%
# LOAD/EXTRACT the data FROM the SQL database
katrina_from_sql_df = pd.read_sql_query("select * from hurricanes where name = 'KATRINA'", con=engine)
coords = katrina_from_sql_df[["new_latitude", "new_longitude"]]

# EXTRACT Google Maps data
fig = gmaps.figure(zoom_level=5, center=(27.5,-85))

#heat_layer = gmaps.heatmap_layer(coords, dissipating=False, max_intensity=100, point_radius=3)
#fig.add_layer(heat_layer)

# TRANSFORM the EXTRACTED data into a Google Maps symbol layer
hurricane_katrina_layer = gmaps.symbol_layer(
    coords, fill_color='red', stroke_color='red', scale=2
)
fig.add_layer(hurricane_katrina_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
